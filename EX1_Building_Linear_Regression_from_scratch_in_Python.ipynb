# %% [markdown]
# #  19CSE305:Machine Learning
#
# ## Linear Regression:Gradient Descent

# %% [markdown]
# Linear Regression:
#
# **Y = wX + b**
#
# Y --> Dependent Variable
#
# X --> Independent Variable
#
# w --> weight
#
# b --> bias

# %% [markdown]
# **Gradient Descent:**
#
# Gradient Descent is an optimization algorithm used for minimizing the loss function in various machine learning algorithms. It is used for updating the parameters of the learning model.
#
# w  =  w - α*dw
#
# b  =  b - α*db

# %% [markdown]
# **Learning Rate:**
#
# Learning rate is a tuning parameter in an optimization algorithm that determines the step size at each iteration while moving toward a minimum of a loss function.

# %% [markdown]
# ![dw.png](data:image/png;base64,...)

# %% [markdown]
# ![db.png](data:image/png;base64,...)

# %%
# Making the imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (12.0, 9.0)

# Preprocessing Input data
data = pd.read_csv('https://raw.githubusercontent.com/harinyadevi/Machine-Learning/main/data_2.csv')
X = data.iloc[:, 0]
Y = data.iloc[:, 1]
plt.scatter(X, Y)
plt.show()

# %%
# Building the model
m = 0
c = 0

L = 0.0001  # The learning Rate
epochs = 300000  # The number of iterations to perform gradient descent

n = float(len(X)) # Number of elements in X

# Performing Gradient Descent 
for i in range(epochs): 
    Y_pred = m*X + c  # The current predicted value of Y
    D_m = (-2/n) * sum(X * (Y - Y_pred))  # Derivative wrt m
    D_c = (-2/n) * sum(Y - Y_pred)  # Derivative wrt c
    m = m - L * D_m  # Update m
    c = c - L * D_c  # Update c
    
print (m, c)
# Out:
# 1.3086537317574174 8.822464803204838

# %% [markdown]
# **Linear Regression**

# %%
# Making predictions
Y_pred = m*X + c

plt.scatter(X, Y)
plt.plot([min(X), max(X)], [min(Y_pred), max(Y_pred)], color='red') # predicted
plt.show()

# %% [markdown]
# ## **Linear Regression using SKLEARN**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('https://raw.githubusercontent.com/harinyadevi/Machine-Learning/main/data_2.csv')
X = data.iloc[:, 0].values.reshape(-1, 1) # values converts it into a numpy array
Y = data.iloc[:, 1].values.reshape(-1, 1) # -1 means that calculate the dimension of rows, but have 1 column
LR = LinearRegression()
LR.fit(X, Y)
Y_pred =LR.predict(X)

# %%
plt.scatter(X, Y)
plt.plot(X, Y_pred, color='red')
plt.show()

# %%
print(LR.intercept_) # Yintercept
print(LR.coef_) #Slope
# Out:
# [9.90860619]
# [[1.28735737]]

# %% [markdown]
# # **Exercise 1**
# Download the dataset from the following link:
# https://drive.google.com/open?id=1oakZCv7g3mlmCSdv9J8kdSaqO5_6dIOw

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/harinyadevi/Machine-Learning/main/student_scores.csv')
# Display first 5 records from the dataset
df1.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
#Display the statistical details of the dataset
df1.describe(include="all")
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %%
#Split the independent and dependent variables and plot the data
X = df1.drop(columns = 'Scores', axis=1)
Y = df1['Scores']

# %%
print(X)
# Out:
#     Hours
# 0     2.5
# 1     5.1
# 2     3.2
# 3     8.5
# 4     3.5
# 5     1.5
# 6     9.2
# 7     5.5
# 8     8.3
# 9     2.7
# 10    7.7
# 11    5.9
# 12    4.5
# 13    3.3
# 14    1.1
# 15    8.9
# 16    2.5
# 17    1.9
# 18    6.1
# 19    7.4
# 20    2.7
# 21    4.8
# 22    3.8
# 23    6.9
# 24    7.8

# %%
print(Y)
# Out:
# 0     21
# 1     47
# 2     27
# 3     75
# 4     30
# 5     20
# 6     88
# 7     60
# 8     81
# 9     25
# 10    85
# 11    62
# 12    41
# 13    42
# 14    17
# 15    95
# 16    30
# 17    24
# 18    67
# 19    69
# 20    30
# 21    54
# 22    35
# 23    76
# 24    86
# Name: Scores, dtype: int64

# %% [markdown]
# Explore  Scikit-Learn's built-in [train_test_split() ](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html) method

# %%
from sklearn.model_selection import train_test_split
#Split the data into train and test set :  80% of the data to training set and 20% data to test set
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3)

# %%
print(X_train)
print(X_test)
# Out:
#     Hours
# 23    6.9
# 4     3.5
# 13    3.3
# 3     8.5
# 24    7.8
# 21    4.8
# 7     5.5
# 1     5.1
# 19    7.4
# 12    4.5
# 16    2.5
# 5     1.5
# 11    5.9
# 15    8.9
# 17    1.9
# 2     3.2
# 22    3.8
#     Hours
# 18    6.1
# 0     2.5
# 9     2.7
# 14    1.1
# 20    2.7
# 8     8.3
# 6     9.2
# 10    7.7

# %%
print(Y_train)
print(Y_test)
# Out:
# 23    76
# 4     30
# 13    42
# 3     75
# 24    86
# 21    54
# 7     60
# 1     47
# 19    69
# 12    41
# 16    30
# 5     20
# 11    62
# 15    95
# 17    24
# 2     27
# 22    35
# Name: Scores, dtype: int64
# 18    67
# 0     21
# 9     25
# 14    17
# 20    30
# 8     81
# 6     88
# 10    85
# Name: Scores, dtype: int64

# %%
#Train an linear regression model and display the parameters (m,c)
# Building the model
m = 0
c = 0
df1 = pd.read_csv('https://raw.githubusercontent.com/harinyadevi/Machine-Learning/main/student_scores.csv')
X = data.iloc[:, 0]
Y = data.iloc[:, 1]
L = 0.0001  # The learning Rate
epochs = 300000  # The number of iterations to perform gradient descent

n = float(len(X)) # Number of elements in X

# Performing Gradient Descent 
for i in range(epochs): 
    Y_pred = m*X + c  # The current predicted value of Y
    D_m = (-2/n) * sum(X * (Y - Y_pred))  # Derivative wrt m
    D_c = (-2/n) * sum(Y - Y_pred)  # Derivative wrt c
    m = m - L * D_m  # Update m
    c = c - L * D_c  # Update c
    
print (m, c)
# Out:
# 1.3086537317574174 8.822464803204838

# %% [markdown]
# Explore sk learn predict method

# %%
# Creating the cost and gradient function
#calculate cost
def CostFunction(x,y,w,b):
    cost = np.sum((((x.dot(w) + b) - y) ** 2) / (2*len(y)))
    return cost

# %%
#Gradient Descent
def GradientDescent(x, y, w, b, learning_rate, epochs):
    cost_list = [0] * epochs
   
    for epoch in range(epochs):
        z = x.dot(w) + b
        loss = z - y
        
        weight_gradient = x.T.dot(loss) / len(y)
        bias_gradient = np.sum(loss) / len(y)
        
        w = w - learning_rate*weight_gradient
        b = b - learning_rate*bias_gradient
  
        cost = CostFunction(x, y, w, b)
        cost_list[epoch] = cost
        
        if (epoch%(epochs/10)==0):
            print("Cost at epoch",epoch,"is:",cost)
        
    return w, b, cost_list

# %%
#Make predictions for the test data

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

w, b, c= GradientDescent(X_train, Y_train, np.zeros(X_train.shape[1]), 0, 0.002,epochs=15000)
def predict(X, w, b):
    return X.dot(w) + b
# Out:
# Cost at epoch 0 is: 1383.2419845539987
# Cost at epoch 1500 is: 16.317158606508098
# Cost at epoch 3000 is: 16.295308523629863
# Cost at epoch 4500 is: 16.286966838587325
# Cost at epoch 6000 is: 16.28378224154316
# Cost at epoch 7500 is: 16.282566461004567
# Cost at epoch 9000 is: 16.28210231364229
# Cost at epoch 10500 is: 16.281925116551946
# Cost at epoch 12000 is: 16.28185746818987
# Cost at epoch 13500 is: 16.281831642139988
